# %% [markdown]
# # COMPETENCIA KAGGLE

# %% [markdown]
# ## ETL

# %% [markdown]
# ### DATOS TABULARES

# %% [markdown]
# Primero se analizarán los datos tabulares.
# A continuación s realizará la improtación de las librerías y la lectura de datos.

# %%
import os

# %%
path_wd = r"C:\Users\rodri\OneDrive\Documentos\Maestría Ciencia de Datos\LAB 2\Datos_Kaggle"
os.chdir(path_wd)

# %%
#!pip install "dask[complete]"

# %%
import dask.dataframe as dd
import pandas as pd

# %%
train_data = dd.read_csv(r".\train\train.csv")

# %%
train_data.describe().compute()
# Out:
#                Type           Age        Breed1        Breed2        Gender  \
# count  14993.000000  14993.000000  14993.000000  14993.000000  14993.000000
# mean       1.457614     10.452078    265.272594     74.009738      1.776162
# std        0.498217     18.155790     60.056818    123.011575      0.681592
# min        1.000000      0.000000      0.000000      0.000000      1.000000
# 25%        1.000000      2.000000    265.000000      0.000000      1.000000
# 50%        1.000000      3.000000    266.000000      0.000000      2.000000
# 75%        2.000000     12.000000    307.000000    179.000000      2.000000
# max        2.000000    255.000000    307.000000    307.000000      3.000000
#
#              Color1        Color2        Color3  MaturitySize     FurLength  \
# count  14993.000000  14993.000000  14993.000000  14993.000000  14993.000000
# mean       2.234176      3.222837      1.882012      1.862002      1.467485
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\rodri\OneDrive\Documentos\GitHub\LAB 2\DMA_LAB2\TP Final\TP FINAL - Datos Tabulares.ipynb Cell 11 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/rodri/OneDrive/Documentos/GitHub/LAB%202/DMA_LAB2/TP%20Final/TP%20FINAL%20-%20Datos%20Tabulares.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> a = train_data.dtypes.reset_index
# ----> <a href='vscode-notebook-cell:/c%3A/Users/rodri/OneDrive/Documentos/GitHub/LAB%202/DMA_LAB2/TP%20Final/TP%20FINAL%20-%20Datos%20Tabulares.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> a[1]
#
# TypeError: 'method' object is not subscriptable
